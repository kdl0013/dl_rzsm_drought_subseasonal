# %%
import pandas as pd

# %%
pd.read_csv('Losses_with_OBS/Wk_0/Wk0_EX10_RZSM')
# Out:
#      Unnamed: 0      loss  RZSM_output_1_loss  RZSM_output_2_loss  \
# 0             0  0.449037            0.158545            0.179497
# 1             1  0.250222            0.093709            0.071103
# 2             2  0.215942            0.082569            0.058508
# 3             3  0.198280            0.076628            0.053192
# 4             4  0.187205            0.072813            0.050176
# ..          ...       ...                 ...                 ...
# 128         128  0.058837            0.021480            0.025510
# 129         129  0.058798            0.021440            0.025449
# 130         130  0.058480            0.021401            0.025388
# 131         131  0.058293            0.021353            0.025341
# 132         132  0.058262            0.021301            0.025287
#
#      RZSM_output_3_loss  RZSM_output_1_mae  RZSM_output_2_mae  \
# 0              0.110995           0.166305           0.184585
# ...

# %%
# Out:
# 0.0096

# %%
.08*.19
# Out:
# 0.0152

# %%
0.02*4 - (.08*.12)
# Out:
# 0.0704
